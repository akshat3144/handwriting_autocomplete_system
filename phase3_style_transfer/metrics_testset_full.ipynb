# %% [markdown]
# # HiGAN+ Model Evaluation - FULL TEST DATASET
#
# This notebook provides comprehensive evaluation using the **FULL TEST DATASET** with **CORRECTED PREPROCESSING**.
#
# ## Key Improvements over previous version:
# 1. **Fixed FID/KID/IS Preprocessing** - Images are already in [-1,1], no double-normalization
# 2. **Significantly More Samples** - Uses full test set (~10,000+ samples) for reliable metrics
# 3. **Uses testset_words64_OrgSz.hdf5** - Official IAM test split
#
# ## Evaluation Pipeline:
# 1. **Load Pre-trained Model** - Restore all network components from checkpoint
# 2. **Quantitative Metrics** - FID, KID, IS, CER, WER, SSIM, PSNR
# 3. **Qualitative Analysis** - Visualizations, style transfer, interpolation
# 4. **Performance Report** - Comprehensive summary and comparison
#
# ## Sample Counts:
# - **Random Generation**: 10,000 samples
# - **Style-Guided Generation**: Full test set (~10,000+ samples)
# - **FID/KID Calculation**: Full test set real vs generated

# %% [markdown]
# ## 1. Load Pre-trained Model and Configuration

# %%
import sys
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import h5py
import cv2
from datetime import datetime
import json
import pandas as pd
from pathlib import Path

# Fix for Pillow>=10
if not hasattr(Image, "ANTIALIAS"):
    Image.ANTIALIAS = Image.Resampling.LANCZOS

# Add project paths
project_path = r'B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer'
sys.path.insert(0, project_path)

# Import HiGAN+ modules
from lib.datasets import get_dataset, get_collect_fn, Hdf5Dataset
from lib.alphabet import strLabelConverter, Alphabets, get_lexicon, get_true_alphabet
from lib.utils import yaml2config, draw_image, AverageMeter
from networks import get_model
from networks.BigGAN_networks import Generator, Discriminator, PatchDiscriminator
from networks.module import Recognizer, WriterIdentifier, StyleEncoder, StyleBackbone
from torch.utils.data import DataLoader

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\nUsing device: {device}")

# Create output directory for results
output_dir = Path(project_path) / "evaluation_results"
output_dir.mkdir(exist_ok=True)
print(f"Results will be saved to: {output_dir}")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_40480\2014288199.py:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   if not hasattr(Image, "ANTIALIAS"):
# PyTorch version: 2.8.0+cu129
# CUDA available: True
# CUDA device: NVIDIA GeForce RTX 4050 Laptop GPU
#
# Using device: cuda
# Results will be saved to: B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\evaluation_results

# %%
# Load configuration
config_path = os.path.join(project_path, 'configs', 'gan_iam.yml')
cfg = yaml2config(config_path)

# Override config settings
cfg.device = str(device)
cfg.training.batch_size = 16
cfg.training.eval_batch_size = 32

print("Configuration loaded:")
print(f"  Dataset: {cfg.dataset}")
print(f"  Model: {cfg.model}")
print(f"  Image height: {cfg.img_height}")
print(f"  Character width: {cfg.char_width}")
# Out:
# Configuration loaded:
#   Dataset: iam_word_org
#   Model: gl_adversarial_model
#   Image height: 64
#   Character width: 32

# %%
# Load checkpoint
checkpoint_path = r"B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\server_updated\checkpoints\epoch_35.pth"

print(f"\nLoading checkpoint from: {checkpoint_path}")
checkpoint = torch.load(checkpoint_path, map_location=device)

print("\nCheckpoint contents:")
for key in checkpoint.keys():
    print(f"  • {key}")

trained_epoch = checkpoint.get('epoch', 'Unknown')
print(f"\nTrained Epoch: {trained_epoch}")
# Out:
# Loading checkpoint from: B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\server_updated\checkpoints\epoch_35.pth
#
# Checkpoint contents:
#   • epoch
#   • iter_count
#   • history
#   • generator
#   • style_encoder
#   • discriminator
#   • patch_discriminator
#   • optimizer_G
#   • optimizer_D
#
# Trained Epoch: 37
#
# Checkpoint contents:
#   • epoch
#   • iter_count
#   • history
#   • generator
#   • style_encoder
#   • discriminator
#   • patch_discriminator
#   • optimizer_G
#   • optimizer_D
#
# Trained Epoch: 37

# %%
# Initialize model architectures
print("\nInitializing model architectures...")

# Generator
generator = Generator(**cfg.GenModel).to(device)
generator.load_state_dict(checkpoint['generator'])
generator.eval()
print(f"✓ Generator loaded - Style dim: {generator.style_dim}")

# Discriminators
discriminator = Discriminator(**cfg.DiscModel).to(device)
discriminator.load_state_dict(checkpoint['discriminator'])
discriminator.eval()

patch_discriminator = PatchDiscriminator(**cfg.PatchDiscModel).to(device)
patch_discriminator.load_state_dict(checkpoint['patch_discriminator'])
patch_discriminator.eval()
print(f"✓ Discriminators loaded")

# Style Encoder & Backbone
style_backbone = StyleBackbone(**cfg.StyBackbone).to(device)
style_encoder = StyleEncoder(**cfg.EncModel).to(device)
style_encoder.load_state_dict(checkpoint['style_encoder'])
style_encoder.eval()
print(f"✓ Style Encoder loaded")

# Recognizer (OCR) - will be loaded from pretrained in next cell
recognizer = Recognizer(**cfg.OcrModel).to(device)
print(f"✓ Recognizer initialized")

# Writer Identifier - will be loaded from pretrained in next cell
writer_identifier = WriterIdentifier(**cfg.WidModel).to(device)
print(f"✓ Writer Identifier initialized (weights loaded from pretrained)")

# Count parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n--- Model Parameters ---")
print(f"Generator: {count_parameters(generator):,}")
print(f"Discriminator: {count_parameters(discriminator):,}")
print(f"Style Encoder: {count_parameters(style_encoder):,}")
print(f"Writer ID: {count_parameters(writer_identifier):,}")
# Out:
# Initializing model architectures...
# ✓ Generator loaded - Style dim: 32
# ✓ Discriminators loaded
# ✓ Style Encoder loaded
# ✓ Recognizer initialized
# ✓ Writer Identifier initialized (weights loaded from pretrained)
#
# --- Model Parameters ---
# Generator: 3,935,937
# Discriminator: 2,366,145
# Style Encoder: 148,032
# Writer ID: 161,396
# ✓ Recognizer initialized
# ✓ Writer Identifier initialized (weights loaded from pretrained)
#
# --- Model Parameters ---
# Generator: 3,935,937
# Discriminator: 2,366,145
# Style Encoder: 148,032
# Writer ID: 161,396

# %%
# Load pretrained OCR and Writer ID models
print("\nLoading pretrained auxiliary models...")

try:
    ocr_path = os.path.join(project_path, cfg.training.pretrained_r)
    wid_path = os.path.join(project_path, cfg.training.pretrained_w)
    
    if os.path.exists(ocr_path):
        r_dict = torch.load(ocr_path, map_location=device)
        recognizer.load_state_dict(r_dict['Recognizer'])
        print(f"✓ Loaded pretrained OCR from {ocr_path}")
    else:
        print(f"⚠ Pretrained OCR not found: {ocr_path}")
    
    if os.path.exists(wid_path):
        w_dict = torch.load(wid_path, map_location=device)
        if 'StyleBackbone' in w_dict:
            style_backbone.load_state_dict(w_dict['StyleBackbone'])
            print(f"✓ Loaded StyleBackbone from {wid_path}")
        if 'WriterIdentifier' in w_dict:
            writer_identifier.load_state_dict(w_dict['WriterIdentifier'])
            print(f"✓ Loaded Writer Identifier from {wid_path}")
        else:
            print(f"⚠ WriterIdentifier key not found in {wid_path}")
            print(f"  Available keys: {list(w_dict.keys())}")
    else:
        print(f"⚠ Pretrained Writer ID not found: {wid_path}")
        
except Exception as e:
    print(f"⚠ Error loading pretrained models: {e}")

recognizer.eval()
writer_identifier.eval()
print("\n✓ All models loaded and set to evaluation mode")
# Out:
# Loading pretrained auxiliary models...
# ✓ Loaded pretrained OCR from B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\./pretrained/ocr_iam_new.pth
# ✓ Loaded StyleBackbone from B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\./pretrained/wid_iam_new.pth
# ✓ Loaded Writer Identifier from B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\./pretrained/wid_iam_new.pth
#
# ✓ All models loaded and set to evaluation mode
# ✓ Loaded StyleBackbone from B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\./pretrained/wid_iam_new.pth
# ✓ Loaded Writer Identifier from B:\College\DL\handwriting_autocomplete_system\phase3_style_transfer\./pretrained/wid_iam_new.pth
#
# ✓ All models loaded and set to evaluation mode

# %% [markdown]
# ## 2. Setup Evaluation Dataset

# %%
# Create dataset and dataloader
print("Loading evaluation dataset...")

collect_fn = get_collect_fn(cfg.training.sort_input, sort_style=True)

# Import Hdf5Dataset directly to control normalize_wid parameter
from lib.datasets import Hdf5Dataset
from lib.path_config import data_roots, data_paths

try:
    # =========================================================================
    # CRITICAL: Understanding the Writer ID mapping
    # =========================================================================
    # The pretrained WriterIdentifier was trained with normalize_wid=True
    # This means: wids = wids - wids.min()
    # So raw wid 57 becomes 0 if 57 was the minimum in training set
    # 
    # To correctly evaluate:
    # 1. Load training set with normalize_wid=False to get RAW wids
    # 2. Compute min_train_wid = min(raw_training_wids)  
    # 3. For any test sample: normalized_wid = raw_wid - min_train_wid
    # =========================================================================
    
    # Load training dataset first to understand the mapping
    train_tag = cfg.dataset.split('_')[0]
    train_dataset_raw = Hdf5Dataset(
        root=data_roots[train_tag],
        split=data_paths[cfg.dataset][cfg.training.dset_split],
        transforms=None,
        alphabet_key='all',
        process_style=True,
        normalize_wid=False  # RAW wids
    )
    
    # Get the min of raw training wids - this is the offset used during training
    min_train_wid = int(train_dataset_raw.wids.min())
    max_train_wid = int(train_dataset_raw.wids.max())
    unique_train_wids_raw = sorted(set(train_dataset_raw.wids.tolist()))
    
    print(f"Training set raw wids: min={min_train_wid}, max={max_train_wid}")
    print(f"Number of unique writers in training: {len(unique_train_wids_raw)}")
    
    # The normalized wid = raw_wid - min_train_wid
    # So we need this mapping for test set
    
    # Load test dataset with normalize_wid=False
    tag = cfg.valid.dset_name.split('_')[0]
    test_dataset = Hdf5Dataset(
        root=data_roots[tag],
        split=data_paths[cfg.valid.dset_name][cfg.valid.dset_split],
        transforms=None,
        alphabet_key='all',
        process_style=True,
        normalize_wid=False  # RAW wids
    )
    
    test_loader = DataLoader(
        test_dataset,
        batch_size=cfg.training.eval_batch_size,
        shuffle=False,
        collate_fn=collect_fn,
        num_workers=0,
        drop_last=False
    )
    
    print(f"✓ Test samples: {len(test_dataset)}")
    print(f"✓ Test batches: {len(test_loader)}")
    
    # Test set info
    unique_test_wids_raw = sorted(set(test_dataset.wids.tolist()))
    min_test_wid = int(test_dataset.wids.min())
    max_test_wid = int(test_dataset.wids.max())
    print(f"Test set raw wids: min={min_test_wid}, max={max_test_wid}")
    print(f"Number of unique writers in test: {len(unique_test_wids_raw)}")
    
    # Check if test wids are a subset of training wids
    test_in_train = set(unique_test_wids_raw) & set(unique_train_wids_raw)
    print(f"Test writers also in training set: {len(test_in_train)}/{len(unique_test_wids_raw)}")
    
    if len(test_in_train) < len(unique_test_wids_raw):
        missing = set(unique_test_wids_raw) - set(unique_train_wids_raw)
        print(f"⚠️ WARNING: {len(missing)} test writers NOT in training set!")
        print(f"   Missing wids (first 10): {sorted(missing)[:10]}")
    
    # Create the mapping: raw_wid -> normalized_wid (as used during training)
    # normalized_wid = raw_wid - min_train_wid
    def raw_to_normalized(raw_wid):
        return raw_wid - min_train_wid
    
    # Verify the mapping makes sense
    print(f"\n--- Writer ID Mapping Verification ---")
    print(f"Training normalization: raw_wid - {min_train_wid} = normalized_wid")
    print(f"Example: raw_wid {unique_train_wids_raw[0]} -> normalized {raw_to_normalized(unique_train_wids_raw[0])}")
    print(f"Example: raw_wid {unique_train_wids_raw[-1]} -> normalized {raw_to_normalized(unique_train_wids_raw[-1])}")
    
    # Check if normalized wids are contiguous 0 to N-1
    normalized_train_wids = [raw_to_normalized(w) for w in unique_train_wids_raw]
    expected_range = list(range(len(unique_train_wids_raw)))
    if normalized_train_wids == expected_range:
        print(f"✓ Normalized wids are contiguous 0 to {len(unique_train_wids_raw)-1}")
    else:
        print(f"⚠️ Normalized wids are NOT contiguous! This may cause issues.")
        print(f"   First 10 normalized: {normalized_train_wids[:10]}")
    
    # Also create train_loader for reference
    train_loader = DataLoader(
        train_dataset_raw,
        batch_size=cfg.training.eval_batch_size,
        shuffle=True,
        collate_fn=collect_fn,
        num_workers=0,
        drop_last=False
    )
    
    print(f"✓ Train samples (for reference): {len(train_dataset_raw)}")
    
    # Store these for later use
    train_dataset = train_dataset_raw
    wid_min_offset = min_train_wid  # The offset to apply: normalized = raw - offset
    
except Exception as e:
    print(f"❌ Error loading dataset: {e}")
    import traceback
    traceback.print_exc()
    raise
# Out:
# Loading evaluation dataset...
# Training set raw wids: min=0, max=371
# Number of unique writers in training: 372
# Training set raw wids: min=0, max=371
# Number of unique writers in training: 372
# ✓ Test samples: 11170
# ✓ Test batches: 350
# Test set raw wids: min=372, max=499
# Number of unique writers in test: 128
# Test writers also in training set: 0/128
# ⚠️ WARNING: 128 test writers NOT in training set!
#    Missing wids (first 10): [372, 373, 374, 375, 376, 377, 378, 379, 380, 381]
#
# --- Writer ID Mapping Verification ---
# Training normalization: raw_wid - 0 = normalized_wid
# Example: raw_wid 0 -> normalized 0
# Example: raw_wid 371 -> normalized 371
# ✓ Normalized wids are contiguous 0 to 371
# ✓ Train samples (for reference): 52231
# ✓ Test samples: 11170
# ✓ Test batches: 350
# Test set raw wids: min=372, max=499
# Number of unique writers in test: 128
# Test writers also in training set: 0/128
# ⚠️ WARNING: 128 test writers NOT in training set!
#    Missing wids (first 10): [372, 373, 374, 375, 376, 377, 378, 379, 380, 381]
#
# --- Writer ID Mapping Verification ---
# Training normalization: raw_wid - 0 = normalized_wid
# Example: raw_wid 0 -> normalized 0
# Example: raw_wid 371 -> normalized 371
# ✓ Normalized wids are contiguous 0 to 371
# ✓ Train samples (for reference): 52231

# %%
# ============================================================================
# DEBUG: Check Dataset Intersection
# ============================================================================
print("="*70)
print("DEBUG: Checking Train/Test Writer ID Intersection")
print("="*70)

# Ensure datasets are loaded
if 'train_dataset_raw' not in dir() or 'test_dataset' not in dir():
    print("Datasets not loaded. Please run the dataset loading cell above.")
else:
    train_wids = set(train_dataset_raw.wids.tolist())
    test_wids = set(test_dataset.wids.tolist())
    
    print(f"Unique Training WIDs: {len(train_wids)}")
    print(f"Unique Test WIDs: {len(test_wids)}")
    print(f"Train WID range: {min(train_wids)} - {max(train_wids)}")
    print(f"Test WID range: {min(test_wids)} - {max(test_wids)}")
    
    intersection = train_wids.intersection(test_wids)
    print(f"Intersection size: {len(intersection)}")
    
    if len(intersection) == 0:
        print("\n❌ CRITICAL: No intersection between training and test writers!")
        print("The test writers are completely disjoint from training writers.")
        print("Classification-based WIER is IMPOSSIBLE if the model hasn't seen these writers.")
        print("We must use Feature Retrieval (distance-based) evaluation instead.")
    else:
        print(f"\n✓ Found {len(intersection)} shared writers.")
        print(f"First 10 shared: {sorted(list(intersection))[:10]}")
        
        # Check if all test writers are in training
        if len(test_wids - train_wids) > 0:
            print(f"⚠️ {len(test_wids - train_wids)} test writers are NOT in training set.")
        else:
            print("✓ All test writers are present in training set.")
# Out:
# ======================================================================
# DEBUG: Checking Train/Test Writer ID Intersection
# ======================================================================
# Unique Training WIDs: 372
# Unique Test WIDs: 128
# Train WID range: 0 - 371
# Test WID range: 372 - 499
# Intersection size: 0
#
# ❌ CRITICAL: No intersection between training and test writers!
# The test writers are completely disjoint from training writers.
# Classification-based WIER is IMPOSSIBLE if the model hasn't seen these writers.
# We must use Feature Retrieval (distance-based) evaluation instead.

# %%
# Load lexicon and label converter
label_converter = strLabelConverter('all')

lexicon = get_lexicon(
    cfg.training.lexicon,
    get_true_alphabet(cfg.dataset),
    max_length=cfg.training.max_word_len
)

if not lexicon:
    print("Building fallback lexicon from dataset...")
    alphabet = get_true_alphabet(cfg.dataset)
    dataset_words = set()
    for start_idx, length in zip(train_dataset.lb_seek_idxs, train_dataset.lb_lens):
        length = int(length)
        if length <= 1 or length >= cfg.training.max_word_len:
            continue
        raw_word = ''.join(chr(ch) for ch in train_dataset.lbs[start_idx:start_idx + length])
        filtered_word = ''.join(ch for ch in raw_word if ch in alphabet)
        if len(filtered_word) > 1:
            dataset_words.add(filtered_word.lower())
    lexicon = sorted(dataset_words)

print(f"✓ Lexicon loaded: {len(lexicon)} words")
print(f"Sample words: {lexicon[:10]}")
# Out:
# ✓ Lexicon loaded: 465593 words
# Sample words: ['1080', '&c', '10-point', '10th', '11-point', '12-point', '16-point', '18-point', '1st', '2,4,5-t']

# %%
# Visualize sample test data
sample_batch = next(iter(test_loader))

imgs = sample_batch['style_imgs'][:8]
lbs = sample_batch['lbs'][:8]
lb_lens = sample_batch['lb_lens'][:8]
texts = label_converter.decode(lbs, lb_lens)

fig, axes = plt.subplots(2, 4, figsize=(16, 6))
axes = axes.ravel()

for i in range(min(8, imgs.size(0))):
    img = imgs[i].squeeze().numpy()
    img = (1 - img) / 2
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f'"{texts[i]}"', fontsize=10)
    axes[i].axis('off')

plt.suptitle('Sample Test Dataset Images', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'sample_test_images.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Sample visualization saved")
# Out:
# ✓ Sample visualization saved

# %% [markdown]
# ## 3. Generate Sample Images
#
# Generate diverse samples for evaluation using different methods.

# %%
from networks.rand_dist import prepare_z_dist, prepare_y_dist
from networks.utils import idx_to_words

print("Setting up random distributions for sampling...")

# Initialize random distributions
z_dist = prepare_z_dist(cfg.training.eval_batch_size, cfg.EncModel.style_dim, device, seed=42)
y_dist = prepare_y_dist(cfg.training.eval_batch_size, len(lexicon), device, seed=42)

print(f"✓ Style distribution: {z_dist.shape}")
print(f"✓ Text distribution: {y_dist.shape}")
# Out:
# Setting up random distributions for sampling...
# ✓ Style distribution: torch.Size([32, 32])
# ✓ Text distribution: torch.Size([32])

# %%
# Generate samples with random styles
print("Generating random style samples...")
print("Using 10,000 samples for reliable FID/IS scores")

n_random_samples = 10000  # Increased from 100 for reliable metrics
random_generated_imgs = []
random_generated_texts = []
max_label_len = 25

with torch.no_grad():
    for i in tqdm(range(n_random_samples // cfg.training.eval_batch_size), desc="Random Generation"):
        # Sample random texts
        y_dist.sample_()
        sampled_words = idx_to_words(y_dist, lexicon, max_label_len, 0.3, 0.0)
        fake_lbs, fake_lb_lens = label_converter.encode(sampled_words, max_label_len)
        fake_lbs = fake_lbs.to(device)
        fake_lb_lens = fake_lb_lens.to(device)
        
        # Sample random styles
        z_dist.sample_()
        
        # Generate images
        fake_imgs = generator(z_dist, fake_lbs, fake_lb_lens)
        
        random_generated_imgs.append(fake_imgs.cpu())
        random_generated_texts.extend(sampled_words)

random_generated_imgs = torch.cat(random_generated_imgs, dim=0).as_subclass(torch.Tensor)
print(f"✓ Generated {random_generated_imgs.size(0)} random style images")
# Out:
# Generating random style samples...
# Using 10,000 samples for reliable FID/IS scores
# Random Generation: 100%|██████████| 312/312 [00:55<00:00,  5.58it/s]
# ✓ Generated 9984 random style images

# %%
# Generate style-guided samples from FULL test set
print("Generating style-guided samples from FULL TEST SET...")
print(f"Total test samples: {len(test_dataset)}")

style_guided_imgs = []
style_guided_texts = []
style_guided_wids = []  # Collect writer IDs for evaluation
style_guided_lb_lens = []  # Collect label lengths for WIER
reference_imgs = []

with torch.no_grad():
    for batch_idx, batch in enumerate(tqdm(test_loader, desc="Style-Guided Generation (Full Test Set)")):
        # NO LIMIT - use full test set for accurate metrics
            
        real_imgs = batch['style_imgs'].to(device)
        real_img_lens = batch['style_img_lens'].to(device)
        real_lbs = batch['lbs'].to(device)
        real_lb_lens = batch['lb_lens'].to(device)
        
        # Extract style
        enc_z = style_encoder(real_imgs, real_img_lens, style_backbone, vae_mode=False)
        
        # Generate with same content
        fake_imgs = generator(enc_z, real_lbs, real_lb_lens)
        
        style_guided_imgs.append(fake_imgs.cpu())
        reference_imgs.append(real_imgs.cpu())
        texts = label_converter.decode(real_lbs, real_lb_lens)
        style_guided_texts.extend(texts)
        
        # Collect writer IDs (these are now ORIGINAL/RAW IDs, not normalized)
        style_guided_wids.append(batch['wids'])
        # Collect label lengths for computing image lengths
        style_guided_lb_lens.append(real_lb_lens.cpu())

# Pad images to max width before concatenation
max_width_fake = max(img.size(3) for img in style_guided_imgs)
style_guided_imgs = [F.pad(img, (0, max_width_fake - img.size(3)), value=-1.0) for img in style_guided_imgs]
style_guided_imgs = torch.cat(style_guided_imgs, dim=0)

max_width_real = max(img.size(3) for img in reference_imgs)
reference_imgs = [F.pad(img, (0, max_width_real - img.size(3)), value=-1.0) for img in reference_imgs]
reference_imgs = torch.cat(reference_imgs, dim=0)

# Concatenate writer IDs and label lengths
style_guided_wids = torch.cat(style_guided_wids, dim=0)
style_guided_lb_lens = torch.cat(style_guided_lb_lens, dim=0)

print(f"✓ Generated {style_guided_imgs.size(0)} style-guided images")
print(f"✓ Collected {len(style_guided_wids)} writer IDs (raw/original)")
print(f"✓ Writer ID range in test: {style_guided_wids.min().item()} to {style_guided_wids.max().item()}")
# Out:
# Generating style-guided samples from FULL TEST SET...
# Total test samples: 11170
# Style-Guided Generation (Full Test Set): 100%|██████████| 350/350 [00:41<00:00,  8.47it/s]
# ✓ Generated 11170 style-guided images
# ✓ Collected 11170 writer IDs (raw/original)
# ✓ Writer ID range in test: 372 to 499

# %%
# Generate fixed text with varying styles
print("Generating fixed texts with varying styles...")

fixed_texts = ["Hello", "World", "Python", "Deep", "Learning", "Neural", "Network", "Artificial"]
fixed_text_imgs = []

n_style_variations = 50  # Increased for better diversity analysis

with torch.no_grad():
    for text in tqdm(fixed_texts, desc="Fixed Text Generation"):
        text_imgs = []
        
        for _ in range(n_style_variations):
            # Random style
            z = torch.randn(1, generator.style_dim).to(device)
            
            # Encode text
            # Workaround for strLabelConverter unwrapping single-item lists
            lbs, lb_lens = label_converter.encode([text, "padding"], max_label_len)
            lbs = lbs[:1].to(device)
            lb_lens = lb_lens[:1].to(device)
            
            # Generate
            fake_img = generator(z, lbs, lb_lens)
            text_imgs.append(fake_img.cpu())
        
        fixed_text_imgs.append(torch.cat(text_imgs, dim=0))

print(f"✓ Generated {len(fixed_texts)} texts with {n_style_variations} style variations each")
# Out:
# Generating fixed texts with varying styles...
# Fixed Text Generation: 100%|██████████| 8/8 [00:09<00:00,  1.17s/it]
# ✓ Generated 8 texts with 50 style variations each

# %% [markdown]
# ## 4. Calculate FID (Fréchet Inception Distance)
#
# FID measures the quality and diversity of generated images by comparing feature distributions.

# %%
# Install pytorch-fid if not available
try:
    from pytorch_fid import fid_score
    from pytorch_fid.inception import InceptionV3
    print("✓ pytorch-fid available")
except ImportError:
    print("Installing pytorch-fid...")
    import subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pytorch-fid"])
    from pytorch_fid import fid_score
    from pytorch_fid.inception import InceptionV3
    print("✓ pytorch-fid installed")
# Out:
# ✓ pytorch-fid available

# %%
from scipy import linalg
import torchvision.transforms as transforms

def calculate_activation_statistics(imgs, model, batch_size=50, dims=2048, device='cpu'):
    """
    Calculate mean and covariance statistics of inception features.
    
    CRITICAL FIX: Images from HiGAN+ dataset are already normalized to [-1, 1] range
    via Normalize([0.5], [0.5]). The previous code was doing (imgs - 0.5) / 0.5
    which is WRONG for data already in [-1, 1] range!
    
    InceptionV3 expects input in [-1, 1] range, which our images already are.
    
    MEMORY FIX: Process grayscale->RGB conversion per batch, not all at once.
    """
    model.eval()
    
    n_samples = imgs.size(0)
    n_batches = (n_samples + batch_size - 1) // batch_size
    
    pred_arr = np.empty((n_samples, dims))
    
    with torch.no_grad():
        for i in tqdm(range(n_batches), desc="Extracting features"):
            start = i * batch_size
            end = min(start + batch_size, n_samples)
            batch = imgs[start:end]
            
            # Convert grayscale to RGB per batch (memory efficient)
            if batch.size(1) == 1:
                batch = batch.repeat(1, 3, 1, 1)
            
            batch = batch.to(device)
            
            # Resize to 299x299 for InceptionV3
            batch = F.interpolate(batch, size=(299, 299), mode='bilinear', align_corners=False)
            
            pred = model(batch)[0]
            
            if pred.size(2) != 1 or pred.size(3) != 1:
                pred = F.adaptive_avg_pool2d(pred, output_size=(1, 1))
            
            pred = pred.squeeze(3).squeeze(2).cpu().numpy()
            pred_arr[start:end] = pred
            
            # Clear GPU cache periodically
            if i % 50 == 0:
                torch.cuda.empty_cache()
    
    mu = np.mean(pred_arr, axis=0)
    sigma = np.cov(pred_arr, rowvar=False)
    
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """Calculate Fréchet Distance between two Gaussian distributions"""
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)
    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)
    
    diff = mu1 - mu2
    
    # Product might be almost singular
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))
    
    # Numerical error might give slight imaginary component
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError(f'Imaginary component {m}')
        covmean = covmean.real
    
    tr_covmean = np.trace(covmean)
    
    return diff.dot(diff) + np.trace(sigma1) + np.trace(sigma2) - 2 * tr_covmean

print("Setting up Inception V3 model for FID calculation...")
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
inception_model = InceptionV3([block_idx]).to(device)
inception_model.eval()
print("✓ Inception V3 ready")
# Out:
# Setting up Inception V3 model for FID calculation...
# ✓ Inception V3 ready
# ✓ Inception V3 ready

# %%
# Calculate FID score using FULL test set
print("\nCalculating FID score using FULL TEST SET...")
print("This will take a while but gives reliable metrics.")

# Use ALL style-guided images (generated from full test set)
print(f"\nUsing {style_guided_imgs.size(0)} generated images")
print(f"Using {reference_imgs.size(0)} real reference images")

# Calculate statistics
print("\nCalculating real image statistics...")
mu_real, sigma_real = calculate_activation_statistics(
    reference_imgs, inception_model, batch_size=32, device=device
)

print("Calculating generated image statistics...")
mu_fake, sigma_fake = calculate_activation_statistics(
    style_guided_imgs, inception_model, batch_size=32, device=device
)

# Calculate FID
fid_value = calculate_frechet_distance(mu_real, sigma_real, mu_fake, sigma_fake)

print(f"\n{'='*60}")
print(f"FID Score (Full Test Set): {fid_value:.4f}")
print(f"Sample Count: {style_guided_imgs.size(0)} images")
print(f"{'='*60}")
print("(Lower is better. FID < 50 is good, FID < 20 is excellent)")
# Out:
# Calculating FID score using FULL TEST SET...
# This will take a while but gives reliable metrics.
#
# Using 11170 generated images
# Using 11170 real reference images
#
# Calculating real image statistics...
# Extracting features: 100%|██████████| 350/350 [00:41<00:00,  8.34it/s]
# Calculating generated image statistics...
# Extracting features: 100%|██████████| 350/350 [00:43<00:00,  8.06it/s]
# ============================================================
# FID Score (Full Test Set): 4.3622
# Sample Count: 11170 images
# ============================================================
# (Lower is better. FID < 50 is good, FID < 20 is excellent)
# C:\Users\PC\AppData\Local\Temp\ipykernel_31124\1382025885.py:65: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)

# %%
# Calculate KID (Kernel Inception Distance)
print("\nCalculating KID score...")

def extract_inception_features(imgs, model, batch_size=32, device='cpu'):
    """
    Extract Inception features for KID calculation.
    
    FIXED: 
    1. Images are already in [-1, 1] range, no normalization needed!
    2. Process grayscale->RGB per batch to save memory
    """
    model.eval()
    
    features = []
    n_batches = (imgs.size(0) + batch_size - 1) // batch_size
    
    with torch.no_grad():
        for i in tqdm(range(n_batches), desc="Extracting features"):
            start = i * batch_size
            end = min(start + batch_size, imgs.size(0))
            batch = imgs[start:end]
            
            # Convert grayscale to RGB per batch (memory efficient)
            if batch.size(1) == 1:
                batch = batch.repeat(1, 3, 1, 1)
            
            batch = batch.to(device)
            batch = F.interpolate(batch, size=(299, 299), mode='bilinear', align_corners=False)
            feat = model(batch)[0]
            if feat.size(2) != 1:
                feat = F.adaptive_avg_pool2d(feat, (1, 1))
            features.append(feat.squeeze().cpu().numpy())
            
            # Clear GPU cache periodically
            if i % 50 == 0:
                torch.cuda.empty_cache()
                
    return np.concatenate(features, axis=0)

def calculate_kid(real_features, fake_features, num_subsets=100, subset_size=None):
    """Calculate Kernel Inception Distance (KID) using polynomial kernel MMD"""
    n_real = real_features.shape[0]
    n_fake = fake_features.shape[0]
    
    # Use smaller subset size if we don't have enough samples
    if subset_size is None:
        subset_size = min(100, n_real, n_fake)
    else:
        subset_size = min(subset_size, n_real, n_fake)
    
    kid_scores = []
    
    for _ in range(num_subsets):
        # Random subsets
        real_idx = np.random.choice(n_real, subset_size, replace=False)
        fake_idx = np.random.choice(n_fake, subset_size, replace=False)
        
        real_subset = real_features[real_idx]
        fake_subset = fake_features[fake_idx]
        
        # Polynomial kernel k(x, y) = (x·y / d + 1)^3
        d = real_features.shape[1]
        
        # Kernel matrices
        k_rr = (real_subset @ real_subset.T / d + 1) ** 3
        k_ff = (fake_subset @ fake_subset.T / d + 1) ** 3
        k_rf = (real_subset @ fake_subset.T / d + 1) ** 3
        
        # Unbiased MMD estimator
        m = subset_size
        mmd = (k_rr.sum() - np.diag(k_rr).sum()) / (m * (m - 1)) \
            + (k_ff.sum() - np.diag(k_ff).sum()) / (m * (m - 1)) \
            - 2 * k_rf.mean()
        
        kid_scores.append(mmd)
    
    return np.mean(kid_scores), np.std(kid_scores)

# Extract features using full test set (same as FID)
print("Extracting real image features from full test set...")
real_feats = extract_inception_features(reference_imgs, inception_model, device=device)

print("Extracting generated image features...")
fake_feats = extract_inception_features(style_guided_imgs, inception_model, device=device)

# Calculate KID with more subsets for reliability
kid_mean, kid_std = calculate_kid(real_feats, fake_feats, num_subsets=100)

print(f"\n{'='*60}")
print(f"KID Score (Full Test Set): {kid_mean:.6f} ± {kid_std:.6f}")
print(f"KID Score (x1000): {kid_mean*1000:.4f} ± {kid_std*1000:.4f}")
print(f"Sample Count: {reference_imgs.size(0)} images")
print(f"{'='*60}")
print("(Lower is better. KID < 0.01 is good, KID < 0.005 is excellent)")
# Out:
# Calculating KID score...
# Extracting real image features from full test set...
# Extracting features: 100%|██████████| 350/350 [00:43<00:00,  8.00it/s]
# Extracting generated image features...
# Extracting features: 100%|██████████| 350/350 [00:39<00:00,  8.97it/s]
# ============================================================
# KID Score (Full Test Set): 0.001867 ± 0.001339
# KID Score (x1000): 1.8672 ± 1.3394
# Sample Count: 11170 images
# ============================================================
# (Lower is better. KID < 0.01 is good, KID < 0.005 is excellent)

# %% [markdown]
# ## 5. Calculate Inception Score (IS)
#
# IS measures both quality and diversity of generated images.

# %%
from torchvision.models import inception_v3

def calculate_inception_score(imgs, model, batch_size=32, splits=10, device='cpu'):
    """
    Calculate Inception Score.
    
    FIXED: 
    1. Images are already in [-1, 1] range, no normalization needed!
    2. Process in batches to avoid memory issues with large datasets
    """
    model.eval()
    
    n_samples = imgs.size(0)
    n_batches = (n_samples + batch_size - 1) // batch_size
    
    preds = []
    
    with torch.no_grad():
        for i in tqdm(range(n_batches), desc="Computing IS"):
            start = i * batch_size
            end = min(start + batch_size, n_samples)
            batch = imgs[start:end]
            
            # Convert grayscale to RGB per batch (memory efficient)
            if batch.size(1) == 1:
                batch = batch.repeat(1, 3, 1, 1)
            
            batch = batch.to(device)
            
            # Resize to 299x299
            batch = F.interpolate(batch, size=(299, 299), mode='bilinear', align_corners=False)
            
            pred = model(batch)
            pred = F.softmax(pred, dim=1).cpu().numpy()
            preds.append(pred)
            
            # Clear GPU cache periodically
            if i % 50 == 0:
                torch.cuda.empty_cache()
    
    preds = np.concatenate(preds, axis=0)
    
    # Calculate score
    split_scores = []
    
    for k in range(splits):
        part = preds[k * (n_samples // splits): (k + 1) * (n_samples // splits), :]
        py = np.mean(part, axis=0)
        scores = []
        for i in range(part.shape[0]):
            pyx = part[i, :]
            scores.append(np.sum(pyx * np.log(pyx / py + 1e-10)))
        split_scores.append(np.exp(np.mean(scores)))
    
    return np.mean(split_scores), np.std(split_scores)

print("Loading Inception V3 for IS calculation...")
inception_v3_model = inception_v3(pretrained=True, transform_input=False).to(device)
inception_v3_model.eval()
print("✓ Inception V3 loaded")
# Out:
# Loading Inception V3 for IS calculation...
# c:\Users\PC\miniconda3\envs\dl_pro\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\PC\miniconda3\envs\dl_pro\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ✓ Inception V3 loaded

# %%
# Calculate Inception Score using ALL random generated samples
print("\nCalculating Inception Score using ALL random samples...")

# Use all 10,000 random generated samples for reliable IS
is_imgs = random_generated_imgs
print(f"Using {is_imgs.size(0)} generated images for IS calculation")

is_mean, is_std = calculate_inception_score(
    is_imgs, inception_v3_model, batch_size=32, splits=10, device=device
)

print(f"\n{'='*60}")
print(f"Inception Score: {is_mean:.4f} ± {is_std:.4f}")
print(f"Sample Count: {is_imgs.size(0)} images")
print(f"{'='*60}")
print("(Higher is better. IS > 5 is good, IS > 10 is excellent)")
# Out:
# Calculating Inception Score using ALL random samples...
# Using 9984 generated images for IS calculation
# Computing IS: 100%|██████████| 312/312 [00:48<00:00,  6.45it/s]
# ============================================================
# Inception Score: 2.1334 ± 0.0217
# Sample Count: 9984 images
# ============================================================
# (Higher is better. IS > 5 is good, IS > 10 is excellent)

# %% [markdown]
# ## 6. Calculate OCR Metrics (CER & WER)
#
# Evaluate text readability using Character Error Rate and Word Error Rate.

# %%
from distance import levenshtein
from networks.utils import ctc_greedy_decoder

def evaluate_ocr_metrics(model_rec, generated_imgs, generated_labels, generated_label_lens, 
                        label_conv, ctc_len_scale, char_width, device):
    """Calculate CER and WER for generated images"""
    model_rec.eval()
    
    char_errors = 0
    total_chars = 0
    word_errors = 0
    total_words = 0
    
    predictions = []
    ground_truths = []
    
    with torch.no_grad():
        # Process in batches
        batch_size = 32
        n_batches = (generated_imgs.size(0) + batch_size - 1) // batch_size
        
        for i in tqdm(range(n_batches), desc="Running OCR"):
            start = i * batch_size
            end = min(start + batch_size, generated_imgs.size(0))
            
            imgs = generated_imgs[start:end].to(device)
            lbs = generated_labels[start:end]
            lb_lens = generated_label_lens[start:end]
            
            img_lens = lb_lens * char_width
            
            # Run OCR
            logits = model_rec(imgs, img_lens.to(device))
            logits = F.softmax(logits, dim=2).cpu().numpy()
            
            # Decode predictions
            for j, (logit, img_len) in enumerate(zip(logits, img_lens.cpu().numpy())):
                slice_len = int(img_len // ctc_len_scale)
                label = ctc_greedy_decoder(logit[:slice_len])
                decoded_text = label_conv.decode(label)
                predictions.append(decoded_text)
                
                # Debug print for the first sample of the first batch
                if i == 0 and j == 0:
                    # Use .view(1) to ensure length is a 1D tensor, avoiding 0-dim tensor indexing error
                    # in case the library hasn't been reloaded with the fix
                    gt_text = label_conv.decode(lbs[j], lb_lens[j].view(1))
                    print(f"\nDEBUG: Sample 0")
                    print(f"  Img Len: {img_len}")
                    print(f"  Slice Len: {slice_len}")
                    print(f"  Logits Shape: {logit.shape}")
                    print(f"  Max Logits Indices: {logit[:slice_len].argmax(axis=1)}")
                    print(f"  Decoded Indices: {label}")
                    print(f"  Decoded Text: '{decoded_text}'")
                    print(f"  GT Text: '{gt_text}'")
            
            # Ground truth
            ground_truths.extend(label_conv.decode(lbs, lb_lens))
    
    # Calculate errors
    for pred, gt in zip(predictions, ground_truths):
        char_error = levenshtein(pred, gt)
        char_errors += char_error
        total_chars += len(gt)
        total_words += 1
        if char_error > 0:
            word_errors += 1
    
    cer = char_errors / total_chars if total_chars > 0 else 0
    wer = word_errors / total_words if total_words > 0 else 0
    
    return cer, wer, predictions, ground_truths

print("Preparing for OCR evaluation...")
ctc_len_scale = recognizer.len_scale
print(f"CTC length scale: {ctc_len_scale}")
# Out:
# Preparing for OCR evaluation...
# CTC length scale: 16

# %%
# Evaluate OCR on FULL style-guided samples
print("\nEvaluating OCR on FULL style-guided test set...")

# Prepare labels for ALL style-guided images (from full test set)
style_guided_lbs = []
style_guided_lb_lens = []

with torch.no_grad():
    for batch_idx, batch in enumerate(tqdm(test_loader, desc="Collecting labels")):
        # NO LIMIT - use full test set
        style_guided_lbs.append(batch['lbs'])
        style_guided_lb_lens.append(batch['lb_lens'])

# Pad labels to max length before concatenation
if len(style_guided_lbs) > 0:
    max_label_len = max(lbs.size(1) for lbs in style_guided_lbs)
    style_guided_lbs = [F.pad(lbs, (0, max_label_len - lbs.size(1)), value=0) for lbs in style_guided_lbs]

style_guided_lbs = torch.cat(style_guided_lbs, dim=0)
style_guided_lb_lens = torch.cat(style_guided_lb_lens, dim=0)

print(f"Evaluating OCR on {style_guided_imgs.size(0)} images...")

cer_style, wer_style, preds_style, gts_style = evaluate_ocr_metrics(
    recognizer, 
    style_guided_imgs,
    style_guided_lbs,
    style_guided_lb_lens,
    label_converter,
    ctc_len_scale,
    cfg.char_width,
    device
)

print(f"\n{'='*60}")
print(f"OCR Metrics (Full Test Set - Style-Guided Generation):")
print(f"  Character Error Rate (CER): {cer_style*100:.2f}%")
print(f"  Word Error Rate (WER): {wer_style*100:.2f}%")
print(f"  Character Accuracy: {(1-cer_style)*100:.2f}%")
print(f"  Word Accuracy: {(1-wer_style)*100:.2f}%")
print(f"  Sample Count: {style_guided_imgs.size(0)} images")
print(f"{'='*60}")
# Out:
# Evaluating OCR on FULL style-guided test set...
# Collecting labels: 100%|██████████| 350/350 [00:15<00:00, 23.25it/s]
# Evaluating OCR on 11170 images...
# Running OCR:   1%|          | 4/350 [00:01<01:39,  3.49it/s]
# DEBUG: Sample 0
#   Img Len: 448
#   Slice Len: 28
#   Logits Shape: (28, 80)
#   Max Logits Indices: [29  0  0 45 32 32 28 28 38  0 33 33 28 28  0 46 47 47  0 65  0 41 42 42
#   0 42 38 38]
#   Decoded Indices: [np.int64(29), np.int64(45), np.int64(32), np.int64(28), np.int64(38), np.int64(33), np.int64(28), np.int64(46), np.int64(47), np.int64(65), np.int64(41), np.int64(42), np.int64(42), np.int64(38)]
#   Decoded Text: 'breakfast-nok'
#   GT Text: 'breakfast-nok'
# Running OCR: 100%|██████████| 350/350 [00:15<00:00, 23.06it/s]
# ============================================================
# OCR Metrics (Full Test Set - Style-Guided Generation):
#   Character Error Rate (CER): 0.65%
#   Word Error Rate (WER): 2.48%
#   Character Accuracy: 99.35%
#   Word Accuracy: 97.52%
#   Sample Count: 11170 images
# ============================================================

# %%
# Show some OCR predictions vs ground truth
print("\nSample OCR Predictions vs Ground Truth:")
print("-" * 80)

n_samples = min(20, len(preds_style))
correct = 0

for i in range(n_samples):
    match = "✓" if preds_style[i] == gts_style[i] else "✗"
    if preds_style[i] == gts_style[i]:
        correct += 1
    print(f"{match} GT: '{gts_style[i]:15s}' | Pred: '{preds_style[i]:15s}'")

print("-" * 80)
print(f"Accuracy in sample: {correct}/{n_samples} ({100*correct/n_samples:.1f}%)")
# Out:
# Sample OCR Predictions vs Ground Truth:
# --------------------------------------------------------------------------------
# ✓ GT: 'breakfast-nok  ' | Pred: 'breakfast-nok  '
# ✓ GT: 'livingrom      ' | Pred: 'livingrom      '
# ✓ GT: 'ungainly       ' | Pred: 'ungainly       '
# ✓ GT: 'entrance       ' | Pred: 'entrance       '
# ✓ GT: 'faling         ' | Pred: 'faling         '
# ✓ GT: 'shufle         ' | Pred: 'shufle         '
# ✓ GT: 'forward        ' | Pred: 'forward        '
# ✓ GT: 'losely         ' | Pred: 'losely         '
# ✓ GT: 'Heather        ' | Pred: 'Heather        '
# ✗ GT: 'aghast         ' | Pred: 'aghost         '
# ✓ GT: 'thrust         ' | Pred: 'thrust         '
# ✓ GT: 'almost         ' | Pred: 'almost         '
# ✓ GT: 'stod           ' | Pred: 'stod           '
# ✓ GT: 'Steve          ' | Pred: 'Steve          '
# ✓ GT: 'where          ' | Pred: 'where          '
# ✓ GT: 'bench          ' | Pred: 'bench          '
# ✓ GT: 'from           ' | Pred: 'from           '
# ✓ GT: 'rose           ' | Pred: 'rose           '
# ✓ GT: 'came           ' | Pred: 'came           '
# ✓ GT: 'into           ' | Pred: 'into           '
# --------------------------------------------------------------------------------
# Accuracy in sample: 19/20 (95.0%)

# %% [markdown]
# ## 7. Calculate Writer Identification Accuracy
#
# Evaluate how well the model preserves writer-specific characteristics.

# %%
"""
Writer Identification Error Rate (WIER) Calculation

Since test writers are disjoint from training writers, we MUST use RETRIEVAL-BASED evaluation.
We extract style embeddings and perform Nearest Neighbor search.
"""

from networks.utils import _len2mask
from collections import defaultdict
import torch.nn.functional as F

# ============================================================================
# 1. Helper: Extract Embeddings (Fixed)
# ============================================================================
def extract_writer_embeddings(model_wid, model_backbone, imgs, img_lens, device, batch_size=32):
    """
    Extract 256-d writer embeddings manually since model.return_feat is broken.
    We replicate the forward pass but stop before the final classifier.
    """
    model_wid.eval()
    model_backbone.eval()
    
    all_feats = []
    n_samples = imgs.size(0)
    n_batches = (n_samples + batch_size - 1) // batch_size
    
    with torch.no_grad():
        for i in tqdm(range(n_batches), desc="Extracting Features"):
            start = i * batch_size
            end = min(start + batch_size, n_samples)
            
            batch_imgs = imgs[start:end].to(device)
            batch_lens = img_lens[start:end].to(device)
            
            # 1. Get backbone features (CNN)
            # model_backbone returns (feat, all_feats)
            feat, _ = model_backbone(batch_imgs, ret_feats=False)
            
            # 2. Pooling (Global Average Pooling with Mask)
            # Calculate reduced length based on backbone scale
            curr_img_len = batch_lens // model_backbone.reduce_len_scale
            
            # Create mask
            img_len_mask = _len2mask(curr_img_len, feat.size(-1)).unsqueeze(1).float().detach()
            
            # Weighted sum pooling
            wid_feat = (feat * img_len_mask).sum(dim=-1) / (curr_img_len.unsqueeze(1).float() + 1e-8)
            
            # 3. Project to embedding space
            # model_wid.linear_wid is Sequential: [Linear, LeakyReLU, Linear(Classifier)]
            # We want the output after the first Linear+LeakyReLU
            
            embedding = model_wid.linear_wid[0](wid_feat)
            embedding = model_wid.linear_wid[1](embedding)
            
            all_feats.append(embedding.cpu())
            
    return torch.cat(all_feats, dim=0)

# ============================================================================
# 2. Retrieval-Based WIER
# ============================================================================
def calculate_wier_retrieval(model_wid, model_backbone, gen_imgs, gen_lens, gen_wids, 
                            ref_imgs, ref_lens, ref_wids, device, batch_size=32):
    print("Calculating Retrieval-based WIER...")
    
    # Extract features
    gen_feats = extract_writer_embeddings(model_wid, model_backbone, gen_imgs, gen_lens, device, batch_size)
    ref_feats = extract_writer_embeddings(model_wid, model_backbone, ref_imgs, ref_lens, device, batch_size)
    
    # Normalize features (Cosine Similarity)
    gen_feats = F.normalize(gen_feats, p=2, dim=1)
    ref_feats = F.normalize(ref_feats, p=2, dim=1)
    
    # Compute similarity matrix (Gen x Ref)
    # Do this in chunks to avoid OOM
    top1_correct = 0
    top5_correct = 0
    
    n_gen = gen_feats.size(0)
    chunk_size = 100
    
    for i in tqdm(range(0, n_gen, chunk_size), desc="Retrieval Matching"):
        end = min(i + chunk_size, n_gen)
        batch_gen_feats = gen_feats[i:end].to(device)
        batch_gen_wids = gen_wids[i:end]
        
        # Similarity: [Batch, N_Ref]
        sim_matrix = torch.mm(batch_gen_feats, ref_feats.to(device).t())
        
        # Get Top-K matches
        _, topk_indices = torch.topk(sim_matrix, k=5, dim=1)
        topk_indices = topk_indices.cpu()
        
        for j in range(len(batch_gen_wids)):
            query_wid = batch_gen_wids[j].item()
            
            # Top-1 check
            top1_idx = topk_indices[j, 0].item()
            retrieved_wid = ref_wids[top1_idx].item()
            
            if retrieved_wid == query_wid:
                top1_correct += 1
                
            # Top-5 check
            retrieved_wids = [ref_wids[idx].item() for idx in topk_indices[j]]
            if query_wid in retrieved_wids:
                top5_correct += 1
                
    acc_top1 = top1_correct / n_gen
    acc_top5 = top5_correct / n_gen
    
    return acc_top1, acc_top5

# ============================================================================
# Main Execution Logic
# ============================================================================
print("="*70)
print("ROBUST WRITER IDENTIFICATION EVALUATION (RETRIEVAL)")
print("="*70)

# Prepare data
style_guided_img_lens = (style_guided_lb_lens * cfg.char_width).long()
reference_img_lens = (style_guided_lb_lens * cfg.char_width).long() # Same lengths for ref

print("\n--- Method: Retrieval (Feature Matching) ---")
print("Using Nearest Neighbor search in feature space.")
print("This works for unseen writers (Zero-Shot).")

acc1, acc5 = calculate_wier_retrieval(
    writer_identifier, style_backbone,
    style_guided_imgs, style_guided_img_lens, style_guided_wids,
    reference_imgs, reference_img_lens, style_guided_wids, # Use real images as reference
    device
)

print(f"✓ Retrieval Successful")
print(f"  Top-1 Accuracy: {acc1*100:.2f}%")
print(f"  Top-5 Accuracy: {acc5*100:.2f}%")
print(f"  WIER: {(1-acc1)*100:.2f}%")

final_acc1 = acc1
final_acc5 = acc5
method_used = "Retrieval"

# Final Report
print(f"\n{'='*60}")
print(f"FINAL WRITER IDENTIFICATION RESULTS ({method_used} Method)")
print(f"{'='*60}")
print(f"  Writer ID Accuracy (Top-1): {final_acc1*100:.2f}%")
print(f"  Writer ID Accuracy (Top-5): {final_acc5*100:.2f}%")
print(f"  WIER (Writer ID Error Rate): {(1-final_acc1)*100:.2f}%")
print(f"  Sample Count: {style_guided_imgs.size(0)}")
print(f"{'='*60}")

# %%
# Also calculate WIER on REAL images as a baseline
print("\n" + "="*70)
print("BASELINE: WIER ON REAL IMAGES")
print("="*70)

# Use the same method as above
if method_used == "Classification":
    print("Using Classification Method for Baseline...")
    acc1_real, acc5_real, _ = calculate_wier_classification(
        writer_identifier, style_backbone, 
        reference_imgs, reference_img_lens, style_guided_wids, 
        wid_mapping, device
    )

else:
    print("Using Retrieval Method for Baseline (Leave-One-Out)...")
    # For retrieval baseline, we match real images against themselves
    # We must be careful not to match an image to itself (distance 0)
    
    print("Calculating Leave-One-Out accuracy on real images...")
    # Extract features
    ref_feats = extract_writer_embeddings(writer_identifier, style_backbone, reference_imgs, reference_img_lens, device)
    ref_feats = F.normalize(ref_feats, p=2, dim=1)
    
    # Compute similarity matrix
    # Do in chunks to avoid OOM
    top1_correct = 0
    top5_correct = 0
    n_samples = len(style_guided_wids)
    chunk_size = 100
    
    for i in tqdm(range(0, n_samples, chunk_size), desc="Baseline Retrieval"):
        end = min(i + chunk_size, n_samples)
        batch_feats = ref_feats[i:end].to(device)
        batch_wids = style_guided_wids[i:end]
        
        sim_matrix = torch.mm(batch_feats, ref_feats.to(device).t())
        
        # Mask diagonal (self-matches) with -inf
        # The diagonal indices for this batch are [i, i+1, ..., end-1]
        for j in range(end - i):
            sim_matrix[j, i + j] = -float('inf')
            
        _, topk_indices = torch.topk(sim_matrix, k=5, dim=1)
        topk_indices = topk_indices.cpu()
        
        for j in range(len(batch_wids)):
            query_wid = batch_wids[j].item()
            
            # Top-1
            retrieved_wid = style_guided_wids[topk_indices[j, 0]].item()
            if retrieved_wid == query_wid:
                top1_correct += 1
                
            # Top-5
            retrieved_wids = [style_guided_wids[idx].item() for idx in topk_indices[j]]
            if query_wid in retrieved_wids:
                top5_correct += 1
            
    acc1_real = top1_correct / n_samples
    acc5_real = top5_correct / n_samples

print(f"\n{'='*60}")
print(f"WRITER IDENTIFICATION ON REAL IMAGES (Baseline):")
print(f"{'='*60}")
print(f"  Writer ID Accuracy (Top-1): {acc1_real*100:.2f}%")
print(f"  Writer ID Accuracy (Top-5): {acc5_real*100:.2f}%")
print(f"  WIER: {(1-acc1_real)*100:.2f}%")
print(f"{'='*60}")

print(f"\n{'='*60}")
print(f"COMPARISON: Real vs Generated")
print(f"{'='*60}")
print(f"  Real Images Accuracy:      {acc1_real*100:.2f}%")
print(f"  Generated Images Accuracy: {final_acc1*100:.2f}%")
print(f"  Accuracy Drop:             {(acc1_real - final_acc1)*100:.2f}%")
if acc1_real > 0:
    print(f"  Style Preservation Ratio:  {(final_acc1/acc1_real)*100:.1f}%")
print(f"{'='*60}")
# Out:
# ======================================================================
# BASELINE: WIER ON REAL IMAGES
# ======================================================================
# Using Retrieval Method for Baseline (Leave-One-Out)...
# Calculating Leave-One-Out accuracy on real images...
# Extracting Features: 100%|██████████| 350/350 [00:06<00:00, 50.36it/s]
# Extracting Features: 100%|██████████| 350/350 [00:06<00:00, 50.36it/s]
# Baseline Retrieval: 100%|██████████| 112/112 [00:00<00:00, 186.97it/s]
# ============================================================
# WRITER IDENTIFICATION ON REAL IMAGES (Baseline):
# ============================================================
#   Writer ID Accuracy (Top-1): 73.82%
#   Writer ID Accuracy (Top-5): 90.36%
#   WIER: 26.18%
# ============================================================
#
# ============================================================
# COMPARISON: Real vs Generated
# ============================================================
#   Real Images Accuracy:      73.82%
#   Generated Images Accuracy: 51.88%
#   Accuracy Drop:             21.94%
#   Style Preservation Ratio:  70.3%
# ============================================================

# %%
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr

def calculate_image_quality_metrics(real_imgs, generated_imgs):
    """Calculate SSIM and PSNR between real and generated images"""
    ssim_scores = []
    psnr_scores = []
    
    n_samples = min(real_imgs.size(0), generated_imgs.size(0))
    
    for i in tqdm(range(n_samples), desc="Calculating SSIM/PSNR"):
        # Convert to numpy
        real_img = real_imgs[i].squeeze().cpu().numpy()
        gen_img = generated_imgs[i].squeeze().cpu().numpy()
        
        # Normalize to [0, 1]
        real_img = (real_img + 1) / 2
        gen_img = (gen_img + 1) / 2
        
        # Calculate SSIM
        ssim_val = ssim(real_img, gen_img, data_range=1.0)
        ssim_scores.append(ssim_val)
        
        # Calculate PSNR
        psnr_val = psnr(real_img, gen_img, data_range=1.0)
        psnr_scores.append(psnr_val)
    
    return np.mean(ssim_scores), np.std(ssim_scores), np.mean(psnr_scores), np.std(psnr_scores)

print("Calculating SSIM and PSNR...")

ssim_mean, ssim_std, psnr_mean, psnr_std = calculate_image_quality_metrics(
    reference_imgs, style_guided_imgs
)

print(f"\n{'='*60}")
print(f"Image Quality Metrics:")
print(f"  MSSIM: {ssim_mean:.4f} ± {ssim_std:.4f}")
print(f"  PSNR: {psnr_mean:.2f} ± {psnr_std:.2f} dB")
print(f"{'='*60}")
print("SSIM: 1.0 is perfect, > 0.7 is good")
print("PSNR: Higher is better, > 30 dB is good")
# Out:
# Calculating SSIM and PSNR...
# Calculating SSIM/PSNR: 100%|██████████| 11170/11170 [00:18<00:00, 607.00it/s]
# ============================================================
# Image Quality Metrics:
#   MSSIM: 0.8606 ± 0.0670
#   PSNR: 19.35 ± 2.37 dB
# ============================================================
# SSIM: 1.0 is perfect, > 0.7 is good
# PSNR: Higher is better, > 30 dB is good

# %% [markdown]
# ## 9. Style Consistency Analysis
#
# Measure how consistently the model maintains a given writing style across different texts.

# %%
def extract_style_features(model_encoder, model_backbone, imgs, img_lens, device):
    """Extract style features from images"""
    model_encoder.eval()
    model_backbone.eval()
    
    with torch.no_grad():
        imgs = imgs.to(device)
        img_lens = img_lens.to(device)
        features = model_encoder(imgs, img_lens, model_backbone, vae_mode=False)
    
    return features.cpu()

def calculate_style_consistency(features):
    """Calculate variance in style features (lower = more consistent)"""
    # Calculate pairwise distances
    features_np = features.numpy()
    
    # Mean feature vector
    mean_feat = np.mean(features_np, axis=0)
    
    # Calculate variance
    variance = np.mean(np.var(features_np, axis=0))
    
    # Calculate pairwise cosine similarity
    from sklearn.metrics.pairwise import cosine_similarity
    similarities = cosine_similarity(features_np)
    
    # Get upper triangle (excluding diagonal)
    n = similarities.shape[0]
    upper_tri_idx = np.triu_indices(n, k=1)
    pairwise_sims = similarities[upper_tri_idx]
    
    mean_similarity = np.mean(pairwise_sims)
    std_similarity = np.std(pairwise_sims)
    
    return variance, mean_similarity, std_similarity

print("Analyzing style consistency...")

# For each text, extract style features from all variations
consistency_results = []

for text_idx, text in enumerate(tqdm(fixed_texts, desc="Style Consistency")):
    imgs = fixed_text_imgs[text_idx]
    img_lens = torch.ones(imgs.size(0), dtype=torch.int) * imgs.size(3)
    
    # Extract features
    features = extract_style_features(style_encoder, style_backbone, imgs, img_lens, device)
    
    # Calculate consistency
    variance, mean_sim, std_sim = calculate_style_consistency(features)
    
    consistency_results.append({
        'text': text,
        'variance': variance,
        'mean_similarity': mean_sim,
        'std_similarity': std_sim
    })

# Summary
print(f"\n{'='*60}")
print("Style Consistency Results:")
print(f"{'='*60}")

for result in consistency_results:
    print(f"Text: '{result['text']:10s}' | Variance: {result['variance']:.4f} | "
          f"Similarity: {result['mean_similarity']:.4f}±{result['std_similarity']:.4f}")

avg_variance = np.mean([r['variance'] for r in consistency_results])
avg_similarity = np.mean([r['mean_similarity'] for r in consistency_results])

print(f"{'='*60}")
print(f"Average Variance: {avg_variance:.4f} (lower = more consistent)")
print(f"Average Similarity: {avg_similarity:.4f} (higher = more consistent)")
print(f"{'='*60}")
# Out:
# Analyzing style consistency...
# Style Consistency: 100%|██████████| 8/8 [00:01<00:00,  4.75it/s]
# ============================================================
# Style Consistency Results:
# ============================================================
# Text: 'Hello     ' | Variance: 0.0093 | Similarity: 0.9546±0.0200
# Text: 'World     ' | Variance: 0.0078 | Similarity: 0.9611±0.0164
# Text: 'Python    ' | Variance: 0.0104 | Similarity: 0.9487±0.0231
# Text: 'Deep      ' | Variance: 0.0034 | Similarity: 0.9839±0.0087
# Text: 'Learning  ' | Variance: 0.0167 | Similarity: 0.9015±0.0421
# Text: 'Neural    ' | Variance: 0.0106 | Similarity: 0.9452±0.0270
# Text: 'Network   ' | Variance: 0.0139 | Similarity: 0.9257±0.0342
# Text: 'Artificial' | Variance: 0.0360 | Similarity: 0.7995±0.0867
# ============================================================
# Average Variance: 0.0135 (lower = more consistent)
# Average Similarity: 0.9275 (higher = more consistent)
# ============================================================

# %% [markdown]
# ## 10. Diversity Metrics
#
# Evaluate output diversity to ensure the model doesn't suffer from mode collapse.

# %%
def calculate_diversity_metrics(imgs):
    """Calculate diversity metrics for generated images"""
    imgs_np = imgs.numpy()
    
    # Reshape to (n_samples, -1)
    n_samples = imgs_np.shape[0]
    imgs_flat = imgs_np.reshape(n_samples, -1)
    
    # Calculate pairwise L2 distances
    from sklearn.metrics.pairwise import euclidean_distances
    distances = euclidean_distances(imgs_flat)
    
    # Get upper triangle
    upper_tri_idx = np.triu_indices(n_samples, k=1)
    pairwise_dists = distances[upper_tri_idx]
    
    mean_dist = np.mean(pairwise_dists)
    std_dist = np.std(pairwise_dists)
    
    # Calculate entropy of pixel values
    pixel_values = imgs_flat.flatten()
    hist, _ = np.histogram(pixel_values, bins=50, density=True)
    hist = hist[hist > 0]
    entropy = -np.sum(hist * np.log(hist + 1e-10))
    
    return mean_dist, std_dist, entropy

print("Calculating diversity metrics...")

# Intra-class diversity (same style, different texts)
intra_diversities = []
for text_idx in range(len(fixed_texts)):
    imgs = fixed_text_imgs[text_idx]
    mean_dist, std_dist, entropy = calculate_diversity_metrics(imgs)
    intra_diversities.append({
        'text': fixed_texts[text_idx],
        'mean_dist': mean_dist,
        'std_dist': std_dist,
        'entropy': entropy
    })

# Inter-class diversity (different styles)
inter_mean_dist, inter_std_dist, inter_entropy = calculate_diversity_metrics(random_generated_imgs[:100])

print(f"\n{'='*60}")
print("Diversity Metrics:")
print(f"{'='*60}")

print("\nIntra-class Diversity (same style, different cannot-vary texts):")
for result in intra_diversities:
    print(f"  Text '{result['text']:10s}': Distance={result['mean_dist']:.4f}±{result['std_dist']:.4f}, "
          f"Entropy={result['entropy']:.4f}")

avg_intra_dist = np.mean([r['mean_dist'] for r in intra_diversities])
avg_intra_entropy = np.mean([r['entropy'] for r in intra_diversities])

print(f"\nAverage Intra-class Distance: {avg_intra_dist:.4f}")
print(f"Average Intra-class Entropy: {avg_intra_entropy:.4f}")

print(f"\nInter-class Diversity (different random styles):")
print(f"  Mean Distance: {inter_mean_dist:.4f}±{inter_std_dist:.4f}")
print(f"  Entropy: {inter_entropy:.4f}")

print(f"\n{'='*60}")
print(f"Diversity Ratio (Inter/Intra): {inter_mean_dist / avg_intra_dist:.2f}")
print(f"{'='*60}")
print("(Higher ratio indicates better diversity across different styles)")
# Out:
# Calculating diversity metrics...
#
# ============================================================
# Diversity Metrics:
# ============================================================
#
# Intra-class Diversity (same style, different cannot-vary texts):
#   Text 'Hello     ': Distance=53.7221±8.3195, Entropy=-68.9904
#   Text 'World     ': Distance=48.1861±7.2482, Entropy=-71.8704
#   Text 'Python    ': Distance=54.1134±7.7340, Entropy=-65.8582
#   Text 'Deep      ': Distance=44.0522±6.9422, Entropy=-72.7993
#   Text 'Learning  ': Distance=59.8413±9.5678, Entropy=-63.1164
#   Text 'Neural    ': Distance=55.0792±8.1115, Entropy=-69.4054
#   Text 'Network   ': Distance=57.4367±8.8494, Entropy=-64.3452
#   Text 'Artificial': Distance=67.7321±9.4467, Entropy=-57.6093
#
# Average Intra-class Distance: 55.0204
# Average Intra-class Entropy: -66.7493
#
# Inter-class Diversity (different random styles):
#   Mean Distance: 74.4315±10.9634
#   Entropy: -59.0244
#
# ============================================================
# Diversity Ratio (Inter/Intra): 1.35
# ============================================================
# (Higher ratio indicates better diversity across different styles)
#
# ============================================================
# Diversity Metrics:
# ============================================================
#
# Intra-class Diversity (same style, different cannot-vary texts):
#   Text 'Hello     ': Distance=53.7221±8.3195, Entropy=-68.9904
#   Text 'World     ': Distance=48.1861±7.2482, Entropy=-71.8704
#   Text 'Python    ': Distance=54.1134±7.7340, Entropy=-65.8582
#   Text 'Deep      ': Distance=44.0522±6.9422, Entropy=-72.7993
#   Text 'Learning  ': Distance=59.8413±9.5678, Entropy=-63.1164
#   Text 'Neural    ': Distance=55.0792±8.1115, Entropy=-69.4054
#   Text 'Network   ': Distance=57.4367±8.8494, Entropy=-64.3452
#   Text 'Artificial': Distance=67.7321±9.4467, Entropy=-57.6093
#
# Average Intra-class Distance: 55.0204
# Average Intra-class Entropy: -66.7493
#
# Inter-class Diversity (different random styles):
#   Mean Distance: 74.4315±10.9634
#   Entropy: -59.0244
#
# ============================================================
# Diversity Ratio (Inter/Intra): 1.35
# ============================================================
# (Higher ratio indicates better diversity across different styles)

# %% [markdown]
# ## 11. Qualitative Visualizations - Style Transfer
#
# Visualize reference images, reconstructions, and style-transferred versions.

# %%
# Create comprehensive style transfer visualization
n_examples = 8

fig, axes = plt.subplots(n_examples, 3, figsize=(15, 3*n_examples))

for i in range(n_examples):
    # Reference image
    ref_img = (1 - reference_imgs[i].squeeze().numpy())
    axes[i, 0].imshow(ref_img, cmap='gray')
    axes[i, 0].set_title(f'Reference: "{style_guided_texts[i]}"', fontsize=10)
    axes[i, 0].axis('off')
    
    # Reconstruction
    recon_img = (1 - style_guided_imgs[i].squeeze().numpy())
    axes[i, 1].imshow(recon_img, cmap='gray')
    axes[i, 1].set_title(f'Reconstruction', fontsize=10)
    axes[i, 1].axis('off')
    
    # OCR prediction
    pred_text = preds_style[i] if i < len(preds_style) else ""
    gt_text = gts_style[i] if i < len(gts_style) else ""
    match = "✓" if pred_text == gt_text else "✗"
    
    axes[i, 2].text(0.5, 0.5, f'{match}\nGT: "{gt_text}"\nPred: "{pred_text}"',
                    ha='center', va='center', fontsize=9, 
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    axes[i, 2].axis('off')

plt.suptitle('Style Transfer: Reference → Reconstruction → OCR Verification', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_style_transfer.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Style transfer visualization saved")
# Out:
# ✓ Style transfer visualization saved

# %% [markdown]
# ## 12. Qualitative Visualizations - Random Generation
#
# Display a grid of randomly generated samples.

# %%
# Random generation grid
n_rows = 4
n_cols = 6
n_total = n_rows * n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 10))
axes = axes.ravel()

for i in range(n_total):
    if i < random_generated_imgs.size(0):
        img = (1 - random_generated_imgs[i].squeeze().numpy())
        text = random_generated_texts[i] if i < len(random_generated_texts) else ""
        
        axes[i].imshow(img, cmap='gray')
        axes[i].set_title(f'"{text}"', fontsize=8)
        axes[i].axis('off')

plt.suptitle('Random Style Generation - Diverse Samples', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_random_generation.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Random generation visualization saved")
# Out:
# ✓ Random generation visualization saved

# %% [markdown]
# ## 13. Qualitative Visualizations - Style Interpolation
#
# Show smooth transitions between different writing styles.

# %%
# Generate style interpolation sequences
interpolation_text = "Interpolate"
n_interpolations = 3
n_steps = 8

fig, axes = plt.subplots(n_interpolations, n_steps, figsize=(20, 3*n_interpolations))

with torch.no_grad():
    for interp_idx in range(n_interpolations):
        # Two random styles
        style_a = torch.randn(1, generator.style_dim).to(device)
        style_b = torch.randn(1, generator.style_dim).to(device)
        
        # Encode text
        # Workaround for strLabelConverter unwrapping single-item lists
        text_lbs, text_lb_lens = label_converter.encode([interpolation_text, "padding"], 25)
        text_lbs = text_lbs[:1].to(device)
        text_lb_lens = text_lb_lens[:1].to(device)
        
        for step_idx in range(n_steps):
            alpha = step_idx / (n_steps - 1)
            style_interp = (1 - alpha) * style_a + alpha * style_b
            
            gen_img = generator(style_interp, text_lbs, text_lb_lens)
            
            img_np = (1 - gen_img.squeeze().cpu().numpy())
            axes[interp_idx, step_idx].imshow(img_np, cmap='gray')
            axes[interp_idx, step_idx].set_title(f'α={alpha:.2f}', fontsize=8)
            axes[interp_idx, step_idx].axis('off')

plt.suptitle(f'Style Interpolation: "{interpolation_text}"', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_interpolation.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Style interpolation visualization saved")
# Out:
# ✓ Style interpolation visualization saved

# %% [markdown]
# ## 14. Qualitative Visualizations - Text Variation
#
# Show how the same style renders different text content.

# %%
# Generate same style, different texts
varied_texts = ["Hello", "World", "123", "CAPS", "lower", "Mixed", "Special!", "PyTorch"]

fig, axes = plt.subplots(2, 4, figsize=(16, 6))
axes = axes.ravel()

with torch.no_grad():
    # One consistent style
    consistent_style = torch.randn(1, generator.style_dim).to(device)
    
    for i, text in enumerate(varied_texts):
        # Encode text
        # Workaround for strLabelConverter unwrapping single-item lists
        lbs, lb_lens = label_converter.encode([text, "padding"], 25)
        lbs = lbs[:1].to(device)
        lb_lens = lb_lens[:1].to(device)
        
        # Generate
        gen_img = generator(consistent_style, lbs, lb_lens)
        
        img_np = (1 - gen_img.squeeze().cpu().numpy())
        axes[i].imshow(img_np, cmap='gray')
        axes[i].set_title(f'"{text}"', fontsize=11, fontweight='bold')
        axes[i].axis('off')

plt.suptitle('Same Writing Style - Different Text Content', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_text_variation.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Text variation visualization saved")
# Out:
# ✓ Text variation visualization saved

# %% [markdown]
# ## 15. Cross-Writer Style Transfer Evaluation
#
# Transfer multiple writer styles to the same text content.

# %%
# Cross-writer style transfer
target_text = "Transfer"
n_writers = 8

# Get different writer samples from test set
writer_samples = []
writer_ids = []

with torch.no_grad():
    for batch in test_loader:
        for i in range(batch['style_imgs'].size(0)):
            wid = batch['wids'][i].item()
            if wid not in writer_ids and len(writer_ids) < n_writers:
                writer_ids.append(wid)
                writer_samples.append({
                    'img': batch['style_imgs'][i:i+1],
                    'img_len': batch['style_img_lens'][i:i+1],
                    'wid': wid,
                    'text': label_converter.decode(batch['lbs'][i:i+1], batch['lb_lens'][i:i+1])[0]
                })
        
        if len(writer_ids) >= n_writers:
            break

# Generate target text in each writer's style
fig, axes = plt.subplots(n_writers, 3, figsize=(12, 3*n_writers))

with torch.no_grad():
    # Encode target text
    # Workaround for strLabelConverter unwrapping single-item lists
    target_lbs, target_lb_lens = label_converter.encode([target_text, "padding"], 25)
    target_lbs = target_lbs[:1].to(device)
    target_lb_lens = target_lb_lens[:1].to(device)
    
    for i, sample in enumerate(writer_samples):
        # Reference image
        ref_img = (1 - sample['img'].squeeze().numpy())
        axes[i, 0].imshow(ref_img, cmap='gray')
        axes[i, 0].set_title(f'Writer {sample["wid"]}\n"{sample["text"]}"', fontsize=9)
        axes[i, 0].axis('off')
        
        # Extract style
        style = style_encoder(sample['img'].to(device), sample['img_len'].to(device), 
                             style_backbone, vae_mode=False)
        
        # Generate target text
        gen_img = generator(style, target_lbs, target_lb_lens)
        gen_img_np = (1 - gen_img.squeeze().cpu().numpy())
        axes[i, 1].imshow(gen_img_np, cmap='gray')
        axes[i, 1].set_title(f'Generated\n"{target_text}"', fontsize=9)
        axes[i, 1].axis('off')
        
        # Info
        axes[i, 2].text(0.5, 0.5, f'Writer ID: {sample["wid"]}\nStyle → "{target_text}"',
                       ha='center', va='center', fontsize=9,
                       bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))
        axes[i, 2].axis('off')

plt.suptitle(f'Cross-Writer Style Transfer: Multiple Writers → "{target_text}"', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_cross_writer.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Cross-writer style transfer visualization saved")
# Out:
# ✓ Cross-writer style transfer visualization saved

# %% [markdown]
# ## 16. Attention Map Visualization
#
# Visualize feature maps from the Style Encoder to understand what contributes to style extraction.

# %%
import torch.nn as nn

def extract_feature_maps(model_backbone, img, img_len):
    """Extract intermediate feature maps from style backbone"""
    model_backbone.eval()
    
    feature_maps = []
    
    # Hook to capture intermediate outputs
    def hook_fn(module, input, output):
        feature_maps.append(output.detach().cpu())
    
    # Register hooks on convolutional layers
    hooks = []
    for name, module in model_backbone.named_modules():
        if isinstance(module, nn.Conv2d):
            hooks.append(module.register_forward_hook(hook_fn))
    
    # Forward pass
    with torch.no_grad():
        _ = model_backbone(img.to(device))
    
    # Remove hooks
    for hook in hooks:
        hook.remove()
    
    return feature_maps

# Visualize feature maps for sample images
n_samples = 3
sample_batch = next(iter(test_loader))

fig = plt.figure(figsize=(18, 4*n_samples))

for sample_idx in range(n_samples):
    img = sample_batch['style_imgs'][sample_idx:sample_idx+1]
    img_len = sample_batch['style_img_lens'][sample_idx:sample_idx+1]
    text = label_converter.decode(sample_batch['lbs'][sample_idx:sample_idx+1], 
                                  sample_batch['lb_lens'][sample_idx:sample_idx+1])[0]
    
    # Extract feature maps
    feature_maps = extract_feature_maps(style_backbone, img, img_len)
    
    # Select a few layers to visualize
    n_layers = min(5, len(feature_maps))
    layer_indices = np.linspace(0, len(feature_maps)-1, n_layers, dtype=int)
    
    for i, layer_idx in enumerate(layer_indices):
        feat_map = feature_maps[layer_idx][0]  # First sample in batch
        
        # Average across channels
        feat_map_avg = torch.mean(feat_map, dim=0).numpy()
        
        ax = plt.subplot(n_samples, n_layers + 1, sample_idx * (n_layers + 1) + i + 1)
        
        if i == 0:
            # Show original image
            orig_img = (1 - img.squeeze().numpy())
            ax.imshow(orig_img, cmap='gray')
            ax.set_title(f'Input: "{text}"', fontsize=9)
        else:
            # Show feature map
            im = ax.imshow(feat_map_avg, cmap='viridis')
            ax.set_title(f'Layer {layer_idx}', fontsize=8)
            plt.colorbar(im, ax=ax, fraction=0.046)
        
        ax.axis('off')

plt.suptitle('Style Encoder Feature Maps Visualization', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(output_dir / 'visualization_feature_maps.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Feature maps visualization saved")
# Out:
# ✓ Feature maps visualization saved

# %% [markdown]
# ## 17. Failure Case Analysis
#
# Identify and analyze failure modes of the model.

# %%
# Analyze failures based on OCR errors
print("Analyzing failure cases...")

# Calculate CER for each sample
individual_errors = []
for i, (pred, gt) in enumerate(zip(preds_style, gts_style)):
    char_error = levenshtein(pred, gt)
    cer_individual = char_error / len(gt) if len(gt) > 0 else 0
    
    individual_errors.append({
        'index': i,
        'gt': gt,
        'pred': pred,
        'cer': cer_individual,
        'char_error': char_error,
        'word_length': len(gt)
    })

# Sort by CER
individual_errors.sort(key=lambda x: x['cer'], reverse=True)

# Get worst cases
n_worst = 12
worst_cases = individual_errors[:n_worst]

print(f"\nTop {n_worst} Failure Cases (Highest CER):")
print("-" * 80)
for i, case in enumerate(worst_cases, 1):
    print(f"{i:2d}. GT: '{case['gt']:15s}' | Pred: '{case['pred']:15s}' | "
          f"CER: {case['cer']*100:.1f}% | Len: {case['word_length']}")
# Out:
# Analyzing failure cases...
#
# Top 12 Failure Cases (Highest CER):
# --------------------------------------------------------------------------------
#  1. GT: 'GO             ' | Pred: '60             ' | CER: 100.0% | Len: 2
#  2. GT: 'GO             ' | Pred: '60             ' | CER: 100.0% | Len: 2
#  3. GT: 'Al             ' | Pred: '1l1            ' | CER: 100.0% | Len: 2
#  4. GT: 'Oh             ' | Pred: 'on             ' | CER: 100.0% | Len: 2
#  5. GT: 'Oh             ' | Pred: 'on             ' | CER: 100.0% | Len: 2
#  6. GT: 'ask            ' | Pred: 'cok            ' | CER: 66.7% | Len: 3
#  7. GT: 'BC             ' | Pred: 'B6C            ' | CER: 50.0% | Len: 2
#  8. GT: 'BC             ' | Pred: 'B8C            ' | CER: 50.0% | Len: 2
#  9. GT: 'If             ' | Pred: 'It             ' | CER: 50.0% | Len: 2
# 10. GT: 'We             ' | Pred: 'we             ' | CER: 50.0% | Len: 2
# 11. GT: 'Do             ' | Pred: 'D              ' | CER: 50.0% | Len: 2
# 12. GT: 'NO             ' | Pred: 'No             ' | CER: 50.0% | Len: 2

# %%
# Visualize failure cases
fig, axes = plt.subplots(4, 3, figsize=(15, 12))
axes = axes.ravel()

for i, case in enumerate(worst_cases):
    idx = case['index']
    
    if idx < style_guided_imgs.size(0):
        img = (1 - style_guided_imgs[idx].squeeze().numpy())
        
        axes[i].imshow(img, cmap='gray')
        axes[i].set_title(f"GT: '{case['gt']}'\nPred: '{case['pred']}'\nCER: {case['cer']*100:.1f}%",
                         fontsize=9, color='red')
        axes[i].axis('off')

plt.suptitle('Failure Case Analysis - Highest OCR Errors', fontsize=14, fontweight='bold', color='red')
plt.tight_layout()
plt.savefig(output_dir / 'analysis_failure_cases.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Failure case visualization saved")
# Out:
# ✓ Failure case visualization saved

# %%
# Analyze error patterns
print("\n" + "="*80)
print("Error Pattern Analysis:")
print("="*80)

# By word length
length_bins = [0, 3, 5, 7, 10, 100]
length_errors = {f'{length_bins[i]}-{length_bins[i+1]}': [] 
                 for i in range(len(length_bins)-1)}

for case in individual_errors:
    for i in range(len(length_bins)-1):
        if length_bins[i] <= case['word_length'] < length_bins[i+1]:
            length_errors[f'{length_bins[i]}-{length_bins[i+1]}'].append(case['cer'])
            break

print("\nCER by Word Length:")
for length_range, cers in length_errors.items():
    if cers:
        print(f"  {length_range:8s}: {np.mean(cers)*100:.2f}% ± {np.std(cers)*100:.2f}% "
              f"(n={len(cers)})")

# Character-level analysis
char_errors = {}
for case in individual_errors:
    for char in case['gt']:
        if char not in char_errors:
            char_errors[char] = []
        char_errors[char].append(case['cer'])

# Most problematic characters
sorted_chars = sorted(char_errors.items(), key=lambda x: np.mean(x[1]), reverse=True)
print("\nTop 10 Most Problematic Characters:")
for char, cers in sorted_chars[:10]:
    if len(cers) >= 5:  # Only if appears at least 5 times
        print(f"  '{char}': {np.mean(cers)*100:.2f}% (n={len(cers)})")
# Out:
# ================================================================================
# Error Pattern Analysis:
# ================================================================================
#
# CER by Word Length:
#   0-3     : 0.67% ± 6.69% (n=2099)
#   3-5     : 0.42% ± 3.62% (n=4995)
#   5-7     : 0.72% ± 3.96% (n=2269)
#   7-10    : 0.79% ± 3.71% (n=1471)
#   10-100  : 0.89% ± 2.92% (n=336)
#
# Top 10 Most Problematic Characters:
#   '"': 50.00% (n=6)
#   '3': 41.03% (n=12)
#   'K': 21.80% (n=8)
#   'U': 20.83% (n=6)
#   'O': 16.12% (n=39)

# %% [markdown]
# ## 18. Comprehensive Performance Report
#
# Generate final summary with all metrics, charts, and export results.
